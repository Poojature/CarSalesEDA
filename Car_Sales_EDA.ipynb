# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib # importing library to change the default setting
import matplotlib.pyplot as plt # Visualization
import seaborn as sns # Visualization on top of matplotlib

# Let's change the default setting
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] =8
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
car = pd.read_csv(r"C:\Users\turep\Downloads\Car_sales.csv")
car.head(9)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
car.shape
# Out:
# (157, 16)

# %%
# Drop duplicate rows
car.drop_duplicates(keep ='last')
car.shape
# Out:
# (157, 16)

# %%
# Dropping unnecessary columns
drop_cols = ['Vehicle_type']
car = car.drop(drop_cols, axis = 1)

# %%
len(car.columns)
# Out:
# 15

# %%
car.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
# Sorting w.r.t Fuel Efficiency
car_sort = car.sort_values(by = 'Fuel_efficiency', ascending = False)
car_sort.head(9)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 26     Chevrolet    Metro              21.855                5.160
# 136       Toyota  Corolla             142.535               10.025
# 130       Saturn       SC              24.546               10.590
# 129       Saturn       SL              80.620                9.200
# 25     Chevrolet    Prizm              32.299                9.125
# 57         Honda    Civic             199.685                9.850
# 62       Hyundai   Accent              41.184                5.860
# 139       Toyota   Celica              33.269               15.445
# 131       Saturn       SW               5.223               10.790
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 26                9.235          1.0        55.0       93.1   62.6   149.4
# 136              13.108          1.8       120.0       97.0   66.7   174.0
# ...

# %%
# Replacing space in column names(i apply this in pretty much every problem)
car.columns = car.columns.str.replace(' ', '_')

# %%
# Finding maximum/minimum values through function
def max_min_val(col):
    '''
    This function takes the column name as the argument
    and returns the top and bottom observations in the dataframe
    '''
    first = car[col].idxmax()
    first_obs = pd.DataFrame(car.loc[first])
    
    last = car[col].idxmin()
    last_obs = pd.DataFrame(car.loc[last])
    
    min_max_obs = pd.concat([first_obs, last_obs], axis=1)
    
    return min_max_obs

# %%
max_min_val('Sales_in_thousands')
# Out:
#                             56          83
# Manufacturer              Ford  Mitsubishi
# Model                 F-Series      3000GT
# Sales_in_thousands     540.561        0.11
# __year_resale_value     15.075       20.94
# Price_in_thousands      26.935       25.45
# Engine_size                4.6         3.0
# Horsepower               220.0       161.0
# Wheelbase                138.5        97.2
# Width                     79.1        72.4
# Length                   224.5       180.3
# Curb_weight              4.241       3.131
# Fuel_capacity             25.1        19.8
# Fuel_efficiency           18.0        21.0
# Latest_Launch        8/16/2012   6/29/2012
# Power_perf_factor    89.401935   67.544155

# %%
# Creating histogram for continuous numerical variable
plt.hist(car['Horsepower'],10);

# %%
# Probability Distribution Functions
sns.distplot(car['Horsepower'],10);
# Out:
# C:\Users\turep\AppData\Local\Temp\ipykernel_2504\591814520.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car['Horsepower'],10);
# C:\Users\turep\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Counting it by its category
make_dist = car.groupby('Manufacturer').size();
make_dist
# Out:
# Manufacturer
# Acura          4
# Audi           3
# BMW            3
# Buick          4
# Cadillac       5
# Chevrolet      9
# Chrysler       7
# Dodge         11
# Ford          11
# Honda          5
# Hyundai        3
# Infiniti       1
# Jaguar         1
# Jeep           3
# Lexus          6
# Lincoln        3
# Mercedes-B     9
# Mercury        6
# Mitsubishi     7
# Nissan         7
# Oldsmobile     6
# Plymouth       4
# Pontiac        6
# Porsche        3
# Saab           2
# Saturn         5
# Subaru         2
# Toyota         9
# Volkswagen     6
# Volvo          6
# dtype: int64

# %%
make_dist.plot(title = 'Make Distribution');

# %%
car_num = car.select_dtypes(include = ['float64', 'int64']);
car_num.head(9)
# Out:
#    Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0              16.919               16.360               21.50          1.8
# 1              39.384               19.875               28.40          3.2
# 2              14.114               18.225                 NaN          3.2
# 3               8.588               29.725               42.00          3.5
# 4              20.397               22.255               23.99          1.8
# 5              18.780               23.555               33.95          2.8
# 6               1.380               39.000               62.00          4.2
# 7              19.747                  NaN               26.99          2.5
# 8               9.231               28.675               33.40          2.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# ...

# %%
matplotlib.rcParams['font.size'] = 8
matplotlib.rcParams['figure.figsize'] = (10,6)
car_num.hist(bins=15,xlabelsize=7);

# %%
# Correlation with Price_in_thousands
car_corr = car_num.corr()['Price_in_thousands'][:-1]
car_corr
# Out:
# Sales_in_thousands    -0.304734
# __year_resale_value    0.953840
# Price_in_thousands     1.000000
# Engine_size            0.626875
# Horsepower             0.839744
# Wheelbase              0.110513
# Width                  0.329136
# Length                 0.156935
# Curb_weight            0.526224
# Fuel_capacity          0.423282
# Fuel_efficiency       -0.492157
# Name: Price_in_thousands, dtype: float64

# %%
# Correlation using pairplot
for i in range(0, len(car_num.columns),5):
    sns.pairplot(car_num, y_vars ='Price_in_thousands', x_vars = car_num.columns[i:i+5]  )
# Out:
# C:\Users\turep\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Significant correlation in one plot( Customized Heatmap)
corr = car_num.drop('Price_in_thousands', axis =1).corr()
sns.heatmap(corr[(corr >= 0.5) |(corr <= -0.4)],
           cmap= 'viridis', vmax = 1.0, vmin = -1.0, linewidths = 0.1,
           annot = True, annot_kws={"size":8}, square =True);
# Out:
# C:\Users\turep\anaconda\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
car.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency',
#        'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
# Boxplot for some categorical variables
bp1 = sns.boxplot(y='Manufacturer', x='Horsepower', data = car )

# %%
sns.regplot(x=car['Length'],y=car['Horsepower']);
